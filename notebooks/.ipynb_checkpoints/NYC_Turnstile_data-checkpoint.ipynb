# %%
# Imports
import pandas as pd
from glob import glob
from datetime import datetime, date, time, timedelta

# %%
# Read data files
list_of_data_files = glob('../data/*.txt')
list_of_data_files
# Out:
# ['../data/turnstile_190330.txt',
#  '../data/turnstile_190518.txt',
#  '../data/turnstile_190525.txt',
#  '../data/turnstile_190323.txt',
#  '../data/turnstile_190309.txt',
#  '../data/turnstile_190420.txt',
#  '../data/turnstile_190427.txt',
#  '../data/turnstile_190601.txt',
#  '../data/turnstile_190406.txt',
#  '../data/turnstile_190413.txt',
#  '../data/turnstile_190511.txt',
#  '../data/turnstile_190504.txt',
#  '../data/turnstile_190316.txt',
#  '../data/turnstile_190302.txt']

# %%
# Read data files into pandas dataframes
list_of_dataframes = [pd.read_csv(file, parse_dates=['DATE']) for file in list_of_data_files]
df = pd.concat(list_of_dataframes)
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6989774
# 1  REGULAR  6989795
# 2  REGULAR  6989813
# 3  REGULAR  6989924
# 4  REGULAR  6990200
#
#    EXITS
# 0                                            2370411
# 1                                            2370413
# 2                                            2370436
# 3                                            2370512
# 4                                            2370573

# %%
df.columns = [x.strip() for x in df.columns]
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
# Filter data to daylight hours
times = ['12:00:00', '16:00:00', '20:00:00']
df = df[df['TIME'].isin(times)]

# %%
df.head(10)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  20:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-24  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-24  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-24  20:00:00
# 15  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-25  12:00:00
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-25  16:00:00
# 17  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-25  20:00:00
# 21  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-26  12:00:00
#
#        DESC  ENTRIES    EXITS
# 3   REGULAR  6989924  2370512
# 4   REGULAR  6990200  2370573
# 5   REGULAR  6990562  2370623
# 9   REGULAR  6990860  2370731
# 10  REGULAR  6991054  2370788
# 11  REGULAR  6991295  2370839
# 15  REGULAR  6991651  2371197
# 16  REGULAR  6991935  2371230
# 17  REGULAR  6992684  2371283
# 21  REGULAR  6993111  2371709

# %%
# Add a weekday column
df['WEEKDAY'] = df.apply(lambda row: row['DATE'].weekday(), axis=1)
df.head()
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  20:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-24  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-24  16:00:00
#
#        DESC  ENTRIES    EXITS  WEEKDAY
# 3   REGULAR  6989924  2370512        5
# 4   REGULAR  6990200  2370573        5
# 5   REGULAR  6990562  2370623        5
# 9   REGULAR  6990860  2370731        6
# 10  REGULAR  6991054  2370788        6

# %%
# Calculate the differences between rows for entries and exits
df['EXIT_COUNT'] = df['EXITS'] - df['EXITS'].shift(1)

# %%
df.head()
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-23  20:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-24  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-03-24  16:00:00
#
#        DESC  ENTRIES    EXITS  WEEKDAY  EXIT_COUNT
# 3   REGULAR  6989924  2370512        5         NaN
# 4   REGULAR  6990200  2370573        5        61.0
# 5   REGULAR  6990562  2370623        5        50.0
# 9   REGULAR  6990860  2370731        6       108.0
# 10  REGULAR  6991054  2370788        6        57.0

# %%
gd = df.groupby(['STATION', 'WEEKDAY', 'TIME'], as_index=False).count()

# %%
gd.head()
